# %%
import pandas as pd
import warnings
from src.seed_everything import seed_everything
from src.calc_point_4 import calculating
from src.plotting import plot_ts
warnings.filterwarnings("ignore")

# %%
PATH_TEST = "Задача3. Датасет 3. Контрольный для участников.csv"
PATH_CALC_INCREASE = "data/predictions_increase.pkl"

# %%
seed_everything()

# %% [markdown]
# # Расчет точки номер 4

# %%
calculating()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# расчет точек, которые возрастают
# 100%|██████████| 3/3 [00:08<00:00,  2.76s/it]

# %% [markdown]
# # Загрузка датасета

# %%
test_data = pd.read_csv(PATH_TEST, encoding="cp1251", sep=';', skiprows=[1])

test_data = test_data.rename(columns={'Unnamed: 0': "Параметр"})
test_data['Параметр'] = pd.to_datetime(test_data['Параметр'], infer_datetime_format=True)
test_data.set_index("Параметр", inplace=True)

# %% [markdown]
# # Визуализация

# %% [markdown]
# Сначала загрузим результаты расчетов предсказанных точек

# %%
predictions_increase = pd.read_pickle(PATH_CALC_INCREASE)

# %% [markdown]
# График можно приближать и отдалять меню справа. Чтобы визуализировать определенную характеристику нужно ввести ее название в поле feat

# %%
feat = 'х011'

plot_ts(test_data[feat], predictions_increase[feat])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1195">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="63bc6600-bc1f-4f5d-9b6e-855b8f906375" data-root-id="1198"></div>

# %% [markdown]
# Берем 4ую точку как последнюю точку, которая не вышла на плато в процессе затухания моделирования

# %%
point_4 = "11.10.2019 6:19"
